# %% [markdown]
# <a href="https://colab.research.google.com/github/sayma101/ML-course-Gobeshona-Academy/blob/main/ml_day_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# variable and data type

# %%
name = "sayma"
age = 25
weight = 65.5

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
age = int(input("enter your age: "))

print(f"my age is" , age ,f"i love football")
# Out:
# enter your age: 26
# my age is 26 i love football

# %%
num1 = 5
num1*=20
num2 = 30

# %%
print(num1<=num2)
print(type(num1>num2))
# Out:
# False
# <class 'bool'>

# %%
print(num1>50 and num2==20)
# Out:
# False

# %% [markdown]
# string

# %%
a = 'Bangladesh'
print(a[4])
print(a[0:8])
print(a[6:])
print(a[-10:-4])
print(a[0::3])
# Out:
# l
# Banglade
# desh
# Bangla
# Bgdh

# %%
print(a.upper())
print(a.lower())
# Out:
# BANGLADESH
# bangladesh
